# %% [markdown]
# # Método de Newton y de la Secante

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize
import math

# %% [markdown]
# ## Ejercicio 1
# $$ f(x) = -x^3 − cos x    $$
# $$ P0=-1  $$

# %%
def f(x: float, points: list[float] = [], show: bool = False):
    y = -x**3 - np.cos(x)
    points.append((x, y))
    if show:
        print(f"f({x}) = {y}")
    return y

# %% [markdown]
# ### Método Newton

# %%
x0 = -1
points = []
fder=lambda x, *args: -3*(x**2)+np.sin(x)
x_r = optimize.newton(f, x0,fprime= fder, args=(points, True), maxiter=100)
# Out:
# f(-1.0) = 0.45969769413186023
# f(-0.880332899571582) = 0.04535115463649053
# f(-0.8656841631760818) = 0.0006323133963189731
# f(-0.865474075952977) = 1.289199819121123e-07
# f(-0.8654740331016162) = 5.218048215738236e-15

# %%
x_points = [point[0] for point in points]

plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()

# %% [markdown]
# #### Usando p0=0

# %%
x0 = 0
points = []
fder=lambda x, *args: -3*(x**2)+np.sin(x)
x_r = optimize.newton(f, x0,fprime= fder, args=(points, True), maxiter=100)
# Out:
# f(0.0) = -1.0
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 4
#       2 points = []
#       3 fder=lambda x, *args: -3*(x**2)+np.sin(x)
# ----> 4 x_r = optimize.newton(f, x0,fprime= fder, args=(points, True), maxiter=100)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\optimize\_zeros_py.py:322, in newton(func, x0, fprime, args, tol, maxiter, fprime2, x1, rtol, full_output, disp)
#     318 if disp:
#     319     msg += (
#     320         " Failed to converge after %d iterations, value is %s."
#     321         % (itr + 1, p0))
# --> 322     raise RuntimeError(msg)
#     323 warnings.warn(msg, RuntimeWarning, stacklevel=2)
#     324 return _results_select(
#     325     full_output, (p0, funcalls, itr + 1, _ECONVERR), method)
#
# RuntimeError: Derivative was zero. Failed to converge after 1 iterations, value is 0.0.

# %% [markdown]
# ### Método Secante

# %%
x0 = -1
points = []
x_r = optimize.newton(f, x0, args=(points, True), maxiter=100)
# Out:
# f(-1.0) = 0.45969769413186023
# f(-1.0002) = 0.46046611914174584
# f(-0.8803532711148402) = 0.04541422430849362
# f(-0.8672398597656004) = 0.005321669149070507
# f(-0.8654992563957521) = 7.58871111643522e-05
# f(-0.8654740762871493) = 1.2992535247668968e-07
# f(-0.8654740331026719) = 3.181344077063386e-12

# %%
x_points = [point[0] for point in points]

plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()

# %% [markdown]
# #### Usando p0=0

# %%
x0 = 0
points = []
x_r = optimize.newton(f, x0, args=(points, True), maxiter=100)
# Out:
# f(0.0) = -1.0
# f(0.0001) = -0.999999995001
# f(20004.0008332358) = -8004801960346.906
# f(-2.4990000917363583e-09) = -1.0

# %%
x_points = [point[0] for point in points]

plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()

# %% [markdown]
# ## Ejercicio 2

# %% [markdown]
#  $$a)\ x^3-2x^2-5=0,\ [1,4] $$

# %%
def f(x: float, points: list[float] = [], show: bool = False):
    y = x**3 - 2*x**2 - 5
    points.append((x, y))
    if show:
        print(f"f({x}) = {y}")
    return y

# %%
x0 = 4    #Podemos poner cualquier valor entre 1 y 4 
points = []
fder=lambda x, *args: 3*(x**2)-4*x
x_r = optimize.newton(f, x0,fprime= fder, args=(points, True),tol=0.0001, maxiter=100)
# Out:
# f(4.0) = 27.0
# f(3.15625) = 6.518463134765625
# f(2.778603253182461) = 1.011312336288718
# f(2.694659468384245) = 0.044054142490232095
# f(2.690656340861001) = 9.743178602406033e-05

# %%
x_points = [point[0] for point in points]

plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()

# %% [markdown]
#  $$b)\ x^3+3x^2-1=0,\ [-3,-2] $$

# %%
def f(x: float, points: list[float] = [], show: bool = False):
    y = x**3 + 3*x**2 - 1
    points.append((x, y))
    if show:
        print(f"f({x}) = {y}")
    return y

# %%
x0 = -2.5   #Podemos poner cualquier valor entre -3 y -2 
points = []
fder=lambda x, *args: 3*(x**2)+6*x
x_r = optimize.newton(f, x0,fprime= fder, args=(points, True),tol=0.0001, maxiter=100)
# Out:
# f(-2.5) = 2.125
# f(-3.0666666666666664) = -1.6269629629629598
# f(-2.9008756038647343) = -0.16586034902030988
# f(-2.879719904423836) = -0.0025428197712535905
# f(-2.87938532466927) = -6.312304527966717e-07

# %%
x_points = [point[0] for point in points]

plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()

# %% [markdown]
#  $$c)\ x − cos x = 0,\ [0,pi/2] $$

# %%
def f(x: float, points: list[float] = [], show: bool = False):
    y = x - np.cos(x)
    points.append((x, y))
    if show:
        print(f"f({x}) = {y}")
    return y

# %%
x0 = 0   #Podemos poner cualquier valor entre 0 y pi/2  
points = []
fder=lambda x, *args: 1+np.sin(x)
x_r = optimize.newton(f, x0,fprime= fder, args=(points, True),tol=0.0001, maxiter=100)
# Out:
# f(0.0) = -1.0
# f(1.0) = 0.45969769413186023
# f(0.7503638678402439) = 0.018923073822117442
# f(0.7391128909113617) = 4.6455898990771516e-05

# %%
x_points = [point[0] for point in points]

plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()

# %% [markdown]
#  $$d)\ x − 0.8 - 0.2 sen x = 0,\ [0,pi/2] $$

# %%
def f(x: float, points: list[float] = [], show: bool = False):
    y = x - 0.8 - 0.2 * np.sin(x)
    points.append((x, y))
    if show:
        print(f"f({x}) = {y}")
    return y

# %%
x0 = 0  #Podemos poner cualquier valor entre 0 y pi/2  
points = []
fder=lambda x, *args: 1-0.2*np.cos(x)
x_r = optimize.newton(f, x0,fprime= fder, args=(points, True),tol=0.0001, maxiter=100)
# Out:
# f(0.0) = -0.8
# f(1.0) = 0.03170580303842063
# f(0.9644529683254768) = 0.00010550745317697285
# f(0.9643338890103158) = 1.165181867657239e-09

# %%
x_points = [point[0] for point in points]

plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()

# %% [markdown]
# ## Ejercicio 3

# %% [markdown]
#  $$a)\ 3x-e^x=0,\ [1,2] $$

# %%
def f(x: float, points: list[float] = [], show: bool = False):
    y = 3*x - np.exp(x)
    points.append((x, y))
    if show:
        print(f"f({x}) = {y}")
    return y

# %% [markdown]
# #### Método Secante

# %%
x0 = 1.5  #Podemos poner cualquier valor entre 1 y 2  
points = []
x_r = optimize.newton(f, x0, args=(points, True),tol=0.00001, maxiter=100)
# Out:
# f(1.5) = 0.018310929661935482
# f(1.50025) = 0.01794036732989479
# f(1.512353474758961) = -0.00033646296949463306
# f(1.5121305756715053) = 6.1086840839053025e-06

# %%
x_points = [point[0] for point in points]

plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()

# %% [markdown]
# #### Método Newton

# %%
x0 = 1.5  #Podemos poner cualquier valor entre 1 y 2  
points = []
fder=lambda x, *args: 3-np.exp(x)
x_r = optimize.newton(f, x0,fprime=fder, args=(points, True),tol=0.00001, maxiter=100)
# Out:
# f(1.5) = 0.018310929661935482
# f(1.5123581458677815) = -0.0003436443671569478
# f(1.512134625427124) = -1.1333940630464667e-07

# %%
x_points = [point[0] for point in points]

plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()

# %% [markdown]
#  $$b)\ 2x+3cosx-e^x=0,\ [1,2] $$

# %%
def f(x: float, points: list[float] = [], show: bool = False):
    y = 2*x + 3*np.cos(x)-np.exp(x)
    points.append((x, y))
    if show:
        print(f"f({x}) = {y}")
    return y

# %% [markdown]
# #### Método Secante

# %%
x0 = 1.5  #Podemos poner cualquier valor entre 1 y 2  
points = []
x_r = optimize.newton(f, x0, args=(points, True),tol=0.00001, maxiter=100)
# Out:
# f(1.5) = -1.2694774653349556
# f(1.50025) = -1.2708461555307693
# f(1.2681218384521216) = -0.12370475657389068
# f(1.2430897388832831) = -0.014509902289506105
# f(1.2397634528487866) = -0.00020924663383059539
# f(1.2397147827617196) = -3.6387838298068687e-07

# %%
x_points = [point[0] for point in points]

plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()

# %% [markdown]
# #### Método Newton

# %%
x0 = 1.5  #Podemos poner cualquier valor entre 1 y 2  
points = []
fder=lambda x, *args: 2-3*np.sin(x)-np.exp(x)
x_r = optimize.newton(f, x0,fprime=fder, args=(points, True),tol=0.00001, maxiter=100)
# Out:
# f(1.5) = -1.2694774653349556
# f(1.268096984432167) = -0.12359495788067587
# f(1.240119693460797) = -0.0017384830731534962
# f(1.2397147825931407) = -3.631548928240136e-07

# %%
x_points = [point[0] for point in points]

plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()

# %% [markdown]
# ## Ejercicio 4

# %% [markdown]
# $$f(x)=230x^4+18x^3+9x^2-221x-9$$

# %%
def f(x: float, points: list[float] = [], show: bool = False):
    y = 230*x**4 + 18*x**3+9*x**2-221*x-9
    points.append((x, y))
    if show:
        print(f"f({x}) = {y}")
    return y

# %% [markdown]
# #### Método Secante

# %%
# Primer Intervalo
x0 = -1
x1= 0
points = []
x_r = optimize.newton(f, x0, x1=x1, args=(points, True),tol=0.000001, maxiter=100)
# Out:
# f(-1.0) = 433.0
# f(0) = -9
# f(-0.02036199095022624) = -4.496380927836868
# f(-0.030430247173817815) = -2.2668913669716844
# f(-0.040667407963600403) = 0.0018001625382417785
# f(-0.04065928497591696) = -7.404577626601849e-07

# %%
x_points = [point[0] for point in points]

plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()

# %%
# Segundo Intervalo
x0 = 0
x1= 1
points = []
x_r = optimize.newton(f, x0, x1=x1, args=(points, True),tol=0.000001, maxiter=100)
# Out:
# f(0.0) = -9.0
# f(1) = 27
# f(0.25) = -62.5078125
# f(0.7737627651217597) = -83.83052027901041
# f(-1.285417783520922) = 879.6389856119229
# f(0.594595520402885) = -104.69138947868024
# f(0.3946411046833953) = -88.12894036243685
# f(-0.6693181355515836) = 183.71315974038512
# f(0.0497143976160719) = -19.961021581616702
# f(-0.020754150823816497) = -4.40957429410711
# f(-0.04073533289637811) = 0.016859473350379517
# f(-0.04065922824320606) = -1.331835136042514e-05

# %%
x_points = [point[0] for point in points]

plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()

# %% [markdown]
# #### Método Newton

# %%
# Primer Intervalo
x0 = -0.5
fder=lambda x, *args:920*x**3+54*x**2+18*x-221
points = []
x_r = optimize.newton(f, x0, fprime=fder, args=(points, True),tol=0.000001, maxiter=100)
# Out:
# f(-0.5) = 115.875
# f(-0.15045248868778283) = 24.510270975839106
# f(-0.04181681394887035) = 0.25664077102784333
# f(-0.04065934349732934) = 1.2233998946342695e-05

# %%
x_points = [point[0] for point in points]

plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()

# %%
# Primer Intervalo
x0 = 0.5
fder=lambda x, *args:920*x**3+54*x**2+18*x-221
points = []
x_r = optimize.newton(f, x0, fprime=fder, args=(points, True),tol=0.000001, maxiter=100)
# Out:
# f(0.5) = -100.625
# f(-0.7050898203592815) = 201.8363035194656
# f(-0.3237911142304748) = 65.41842668694188
# f(-0.06460313103057486) = 5.314007069966671
# f(-0.04068615115195558) = 0.005955616485257664
# f(-0.04065928834533494) = 6.557147713692757e-09

# %%
x_points = [point[0] for point in points]

plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()

# %% [markdown]
# ## Ejercicio 5
# $$f(x)=\tan\pi x - 6$$

# %%
def f(x: float, points: list[float] = [], show: bool = False):
    y = np.tan(np.pi*x)-6
    points.append((x, y))
    if show:
        print(f"f({x}) = {y}")
    return y

# %% [markdown]
# #### Método Bisección

# %%
x_r = optimize.bisect(f, 0, 0.48,maxiter=10,xtol=1e-3)
x_r
# Out:
# 0.44718749999999996

# %%
x = np.linspace(-10, 10, 300)

y = f(x)

plt.plot(x, y)

plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfica')
ax = plt.gca()
ax.set_ylim([-20, 4])
ax.set_xlim([-10, 10])
plt.grid(True)
plt.legend(["$y(x)=tan \pi x - 6$"])
plt.show()
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\p'
# <>:14: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\User\AppData\Local\Temp\ipykernel_3584\1508391916.py:14: SyntaxWarning: invalid escape sequence '\p'
#   plt.legend(["$y(x)=tan \pi x - 6$"])

# %% [markdown]
# #### Método Newton

# %%
x0 = 0.48
fder=lambda x, *args:np.pi*(1/np.cos(np.pi*x))**2
points = []
x_r = optimize.newton(f, x0, fprime=fder, args=(points, True), maxiter=10)
# Out:
# f(0.48) = 9.894544843865265
# f(0.4675825019258912) = 3.785105252252814
# f(0.4551291915177739) = 1.046868151861597
# f(0.4485512339384831) = 0.1329583649899968
# f(0.4474551842507058) = 0.002749225198632743
# f(0.4474315538237576) = 1.2245786331632758e-06

# %%
x_points = [point[0] for point in points]

plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()

# %% [markdown]
# #### Método Secante

# %%
points = []
x_r = optimize.newton(f, x0=0,x1=0.48, args=(points, True), maxiter=10)
# Out:
# f(0.0) = -6.0
# f(0.48) = 9.894544843865265
# f(0.18119424169051174) = -5.360105281561882
# f(0.28618716582228976) = -4.7422109536614165
# f(1.0919861065027492) = -5.702694576330456
# f(-3.6922966654010985) = -4.551142530386734
# f(-22.600649854738627) = -2.9435626867471116
# f(-57.22283247053829) = -6.8423718946625085
# f(3.538758217528318) = -14.172079361744972
# f(-113.94452324280343) = -5.823928257201766
# f(-195.9044918726541) = -5.690611560612835
# f(-3694.358600967476) = -8.101088129636398
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[56], line 2
#       1 points = []
# ----> 2 x_r = optimize.newton(f, x0=0,x1=0.48, args=(points, True), maxiter=10)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\scipy\optimize\_zeros_py.py:391, in newton(func, x0, fprime, args, tol, maxiter, fprime2, x1, rtol, full_output, disp)
# ...

# %% [markdown]
# ## Ejercicio 6
# $$f(x)=\ln (x^2+1)-e^{0.4x} \cos \pi x$$

# %%
def f(x: float, points: list[float] = [], show: bool = False):
    y = np.log10((x**2)+1)-np.exp(0.4*x)*np.cos(np.pi*x)
    points.append((x, y))
    if show:
        print(f"f({x}) = {y}")
    return y

# %% [markdown]
# #### a)

# %%
x0 = -0.5
fder=lambda x, *args:(2 * x / (x**2 + 1)) - (0.4 * np.exp(0.4 * x) * np.cos(np.pi * x)) + \
           (np.pi * np.exp(0.4 * x) * np.sin(math.pi * x))
points = []
x_r = optimize.newton(f, x0, fprime=fder, args=(points, True),tol=0.000001)
# Out:
# f(-0.5) = 0.09691001300805636
# f(-0.47126138584451827) = 0.012430014521080515
# f(-0.4675972750418123) = 0.0015928379605060772
# f(-0.4671278685482267) = 0.0002036933996230894
# f(-0.46706784209987406) = 2.6040758721604385e-05
# f(-0.4670601681691786) = 3.328998685131479e-06

# %%
x_points = [point[0] for point in points]

plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()

# %% [markdown]
# #### b)

# %%
x0 = [0.5,1.5,2.5,3.5]
x_r = optimize.newton(f, x0, fprime=fder, args=(points, True),tol=0.000001)
# Out:
# f([0.5 1.5 2.5 3.5]) = [0.09691001 0.51188336 0.86033801 1.12221588]
# f([0.47910138 1.60661398 2.40678278 3.5918984 ]) = [ 0.01027556 -0.07101467  0.0760367  -0.05473131]
# f([0.47684031 1.5923956  2.3976031  3.5875657 ]) = [0.00100777 0.0073345  0.00425931 0.0012783 ]
# f([0.47661801 1.59386042 2.39708094 3.58766686]) = [ 9.78173418e-05 -7.45740507e-04  2.11819936e-04 -2.95974264e-05]
# f([0.47659643 1.59371146 2.39705495 3.58766452]) = [9.48459027e-06 7.58799955e-05 1.04538550e-05 6.85382335e-07]
# f([0.47659434 1.59372662 2.39705367 3.58766457]) = [ 9.19554089e-07 -7.72022721e-06  5.15726895e-07 -1.58712321e-08]
# f([0.47659414 1.59372507 2.3970536  3.58766457]) = [8.91521288e-08 7.85482600e-07 2.54422124e-08 3.67530895e-10]

# %% [markdown]
# #### c)

# %%
x_values = np.linspace(0, 5, 500)  # Intervalo de 0 a 5, con 500 puntos
y_values = f(x_values)

plt.figure(figsize=(8, 6))
plt.plot(x_values, y_values, label='f(x) = ln(x^2 + 1) - e^(0.4x) * cos(πx)', color='b')
plt.axhline(0, color='black',linewidth=0.8) 
plt.axvline(0, color='black',linewidth=0.8)
plt.title("Gráfica de la función f(x)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# #### d)

# %%
# En el literal c vimos que x0 = n + 0.476594 así que usaremos x0=25.476594
x0=25.476594
points = []
x_r = optimize.newton(f, x0, fprime=fder, args=(points, True),tol=0.000001)
# Out:
# f(25.476594) = 1960.8608426425574
# f(25.500298315051378) = -22.40249279847958
# f(25.500033318813035) = -0.002356475396184887

# %% [markdown]
# ## Ejercicio 7

# %%
def f(x: float, points: list[float] = [], show: bool = False):
    y = x**(1/3)
    points.append((x, y))
    if show:
        print(f"f({x}) = {y}")
    return y

# %% [markdown]
# #### Método Newton

# %%
x0 = 1
fder=lambda x, *args:(1/3)*x**(-2/3)
points = []
x_r = optimize.newton(f, x0, fprime=fder, args=(points, True))
# Out:
# f(1.0) = 1.0
# f(-2.0) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# C:\Users\User\AppData\Local\Temp\ipykernel_3584\4094094749.py:2: RuntimeWarning: invalid value encountered in scalar power
#   y = x**(1/3)
# ---------------------------------------------------------------------------
# ...

# %% [markdown]
# #### Método Secante

# %%
points = []
x_r = optimize.newton(f, x0=5,x1=0.5, args=(points, True))
# Out:
# f(5.0) = 1.7099759466766968
# f(0.5) = 0.7937005259840998
# f(-3.398011761822332) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# f(nan) = nan
# C:\Users\User\AppData\Local\Temp\ipykernel_3584\4094094749.py:2: RuntimeWarning: invalid value encountered in scalar power
#   y = x**(1/3)
# ...
